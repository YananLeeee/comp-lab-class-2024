# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the trajectory data
# Replace 'beta_amyloid' with the actual name of your trajectory file
# and ensure the file is in the 'Data' folder.

trajectory_file = '1hz3_T310.stepid25000000.every100ps.nowater.xtc'  # Change to your trajectory file name
topology_file = '1hz3_T310.start.nowater.gro'  # Change to your topology file name

# Load the trajectory and topology
traj = md.load(trajectory_file, top=topology_file)

# Step 2: Compute end-to-end distance and radius of gyration

# Define the end-to-end distance function
def end_to_end_distance(traj):
    # Assume the first and last atoms are the endpoints of the molecule
    # This needs to be adjusted based on your system
    atom_indices = [0, -1]  # Example indices for end atoms
    distances = md.compute_distances(traj, [atom_indices])
    return distances[:, 0]

# Define the radius of gyration function
def compute_radius_of_gyration(traj):
    rg = md.compute_rg(traj)
    return rg

# Compute values
end_to_end_distances = end_to_end_distance(traj)
radii_of_gyration = compute_radius_of_gyration(traj)
times = traj.time  # Time in picoseconds

# Step 3: Plot end-to-end distance and radius of gyration vs. time

plt.figure(figsize=(12, 6))

plt.plot(times, end_to_end_distances, label='End-to-End Distance', color='blue')
plt.plot(times, radii_of_gyration, label='Radius of Gyration', color='red')
plt.xlabel('Time (ps)')
plt.ylabel('Distance / Radius')
plt.title('End-to-End Distance and Radius of Gyration vs Time')
plt.legend()
plt.grid(True)

plt.show()

# Step 4: Plot normalized histograms

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(end_to_end_distances, bins=30, density=True, alpha=0.7, color='blue')
plt.xlabel('End-to-End Distance')
plt.ylabel('Normalized Frequency')
plt.title('Histogram of End-to-End Distance')

plt.subplot(1, 2, 2)
plt.hist(radii_of_gyration, bins=30, density=True, alpha=0.7, color='red')
plt.xlabel('Radius of Gyration')
plt.ylabel('Normalized Frequency')
plt.title('Histogram of Radius of Gyration')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 31
#      28     return rg
#      30 # Compute values
# ---> 31 end_to_end_distances = end_to_end_distance(traj)
#      32 radii_of_gyration = compute_radius_of_gyration(traj)
#      33 times = traj.time  # Time in picoseconds
#
# Cell In[1], line 22, in end_to_end_distance(traj)
#      18 def end_to_end_distance(traj):
#      19     # Assume the first and last atoms are the endpoints of the molecule
#      20     # This needs to be adjusted based on your system
#      21     atom_indices = [0, -1]  # Example indices for end atoms
# ---> 22     distances = md.compute_distances(traj, [atom_indices])
#      23     return distances[:, 0]
#
# File ~/.local/lib/python3.11/site-packages/mdtraj/geometry/distance.py:170, in compute_distances(traj, atom_pairs, periodic, opt)
# ...

# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load the trajectory and topology
trajectory_file = '1hz3_T310.stepid25000000.every100ps.nowater.xtc'  # Change to your trajectory file name
topology_file = '1hz3_T310.start.nowater.gro'  # Change to your topology file name

# Load the trajectory and topology
traj = md.load(trajectory_file, top=topology_file)

# Step 2: Compute end-to-end distance and radius of gyration

# Define the end-to-end distance function
def end_to_end_distance(traj):
    # Select the first and last atoms in the trajectory
    start_atom = traj.topology.select('name CA')[0]  # Example: select the first CA atom
    end_atom = traj.topology.select('name CA')[-1]  # Example: select the last CA atom
    distances = md.compute_distances(traj, [[start_atom, end_atom]])
    return distances[:, 0]

# Define the radius of gyration function
def compute_radius_of_gyration(traj):
    rg = md.compute_rg(traj)
    return rg

# Compute values
end_to_end_distances = end_to_end_distance(traj)
radii_of_gyration = compute_radius_of_gyration(traj)
times = traj.time  # Time in picoseconds

# Step 3: Plot end-to-end distance and radius of gyration vs. time

plt.figure(figsize=(12, 6))

plt.plot(times, end_to_end_distances, label='End-to-End Distance', color='blue')
plt.plot(times, radii_of_gyration, label='Radius of Gyration', color='red')
plt.xlabel('Time (ps)')
plt.ylabel('Distance / Radius')
plt.title('End-to-End Distance and Radius of Gyration vs Time')
plt.legend()
plt.grid(True)

plt.show()

# Step 4: Plot normalized histograms

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(end_to_end_distances, bins=30, density=True, alpha=0.7, color='blue')
plt.xlabel('End-to-End Distance')
plt.ylabel('Normalized Frequency')
plt.title('Histogram of End-to-End Distance')

plt.subplot(1, 2, 2)
plt.hist(radii_of_gyration, bins=30, density=True, alpha=0.7, color='red')
plt.xlabel('Radius of Gyration')
plt.ylabel('Normalized Frequency')
plt.title('Histogram of Radius of Gyration')

plt.tight_layout()
plt.show()
