# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Outputs/metad1_initmonitor/METADYN-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 4] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.title("Potential Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Figures/metad1_initmonitor_Energy.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Outputs/metad1_initmonitor_freqhills/METADYN-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 4] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.title("Potential Energy vs. Time")
plt.ylim(-389, -385)
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Figures/metad1_initmonitor_freqhills_Energy.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Outputs/monitor/MONITOR-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 4] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.title("Potential Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Figures/monitor_Energy.png')
plt.show()
