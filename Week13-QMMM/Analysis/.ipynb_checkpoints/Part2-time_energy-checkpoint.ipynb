# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Outputs/NPT-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 4] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.title("Potential Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Figures/NPT_Energy_NPT.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Outputs/NVT-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 4] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.title("Potential Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week13-QMMM/Figures/NVT_Energy_NPT.png')
plt.show()
