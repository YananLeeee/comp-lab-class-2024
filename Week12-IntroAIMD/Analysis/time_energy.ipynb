# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week12-IntroAIMD/Runs/Water/water_aimd_1ns_every0.5fs-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 2] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("kinetic Energy (a.u.)")
plt.title("Kinetic Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week12-IntroAIMD/Figures/water.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/yl12451/comp-lab-class/comp-lab-class-2024/Week12-IntroAIMD/Runs/Proton/proton_aimd_1ns_every0.5fs-1.ener")  # Replace with your file
time = data[:, 1]  
energy = data[:, 2] 

plt.plot(time, energy)
plt.xlabel("Time (fs)")
plt.ylabel("kinetic Energy (a.u.)")
plt.title("Kinetic Energy vs. Time")
plt.savefig('/home/yl12451/comp-lab-class/comp-lab-class-2024/Week12-IntroAIMD/Figures/proton.png')
plt.show()
